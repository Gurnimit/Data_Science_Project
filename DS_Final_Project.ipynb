# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurnimit/Data_Science_Project/blob/main/DS_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Global Terrorism Data Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Name - Gurnimit Singh**

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Gurnimit/Data_Science_Project

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Global Terrorism Dataset provides a comprehensive record of terrorist incidents that occurred worldwide between 1970 and 2017. This dataset contains detailed information on over 180,000 attacks, including attributes such as date, location, attack type, target type, weapon used, terrorist group involved, and the number of casualties. The dataset serves as a valuable resource for understanding patterns, trends, and the evolving nature of terrorism across different regions and time periods.
#
# The primary objective of this project is to analyze the dataset using exploratory data analysis (EDA) techniques to uncover meaningful insights related to global terrorism. The analysis focuses on identifying trends over time, understanding the geographic distribution of attacks, examining the most common attack methods, and evaluating the impact in terms of casualties and damage.
#
# The project begins with data loading and preprocessing. Missing values in important numerical columns such as the number of people killed and wounded were handled by replacing them with zero. A new feature, “casualties,” was created by combining the number of killed and wounded to better measure the impact of each attack. The dataset was also cleaned and formatted to ensure consistency and accuracy for analysis.
#
# Various visualization techniques were used to explore the data, including bar charts, pie charts, count plots, box plots, histograms, and heatmaps. These visualizations helped in understanding both univariate and multivariate relationships within the dataset. For example, line and bar charts were used to analyze trends in the number of attacks over the years, while pie charts and count plots helped examine the distribution of attacks across regions and attack types. Box plots were used to study the distribution and spread of casualties, highlighting the presence of extreme outliers. Heatmaps and pair plots were utilized to analyze correlations and relationships between numerical variables such as kills, wounds, and total casualties.
#
# The analysis revealed several important insights. There has been a significant increase in the number of terrorist attacks over time, particularly after 2010, with a peak around 2013–2014. The data also shows that terrorism is highly concentrated in specific regions, especially the Middle East & North Africa and South Asia. Countries like Iraq, Pakistan, and Afghanistan have experienced the highest number of attacks. Among attack types, bombing and explosions are the most common methods used by terrorist groups. Although most attacks result in relatively low casualties, a small number of incidents cause extremely high damage, indicating a highly skewed distribution.
#
# Further analysis showed that a limited number of terrorist groups are responsible for a large proportion of attacks, and their activities are often region-specific. Strong correlations were observed between the number of people killed, wounded, and total casualties, confirming that these variables are directly related and critical for assessing the severity of attacks.
#
# Overall, this project demonstrates how data analysis can be used to gain valuable insights into global terrorism. The findings can help governments, organizations, and policymakers make informed decisions regarding security planning, resource allocation, and risk management. By understanding the patterns and factors associated with terrorist activities, more effective preventive measures and strategies can be developed to reduce the impact of such incidents in the future.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# * The problem is to analyze global terrorism data to identify patterns, trends, and key factors influencing terrorist activities.
# * The dataset contains detailed information about attacks, including location, time, attack type, target, and casualties.
# * The goal is to understand how terrorism varies across regions, time periods, and methods.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business Objectives :
# * To identify high-risk regions and countries affected by terrorist attacks.
# * To analyze trends in terrorist activities over time.
# * To understand the relationship between attack type, weapon type, and casualties.
# * To identify major terrorist groups and their areas of operation.
# * To provide insights that support better decision-making, risk assessment, and security planning.e.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')
# Out:
# /tmp/ipykernel_10135/934653908.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')

# %% [markdown]
# ### Dataset First View

# %%
df.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# #### Duplicate Values

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
missing_values = df.isnull().sum().sort_values(ascending=False)
print(df.isnull().sum())
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
plt.figure(figsize=(20,8))
missing_values = missing_values[missing_values > 0]
missing_values.plot(kind='bar')
plt.title('Missing Values')
plt.xlabel('Columns')
plt.ylabel('Number of missing values')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The dataset contains information about global terrorist attacks from 1970 to 2017.
# * It includes details such as date, location, attack type, target, weapon used, and casualties.
# * The dataset has a large number of columns representing different attributes of each incident.
# * Using df.describe(), we observed summary statistics like count, mean, min, and max for numerical variables.
# * Some columns contain missing values, especially in casualty-related fields.
# * The dataset includes both categorical and numerical features.
# * It provides comprehensive information useful for analyzing patterns and trends in terrorism.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(df.columns)
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * eventid – Unique identifier for each terrorist attack.
# * iyear – Year in which the attack occurred.
# * imonth – Month of the attack.
# * iday – Day of the attack.
# * country_txt – Name of the country where the attack occurred.
# * region_txt – Region in which the attack took place.
# * city – City of the attack.
# * latitude / longitude – Geographic coordinates of the attack location.
# * attacktype1_txt – Type of attack (e.g., Bombing, Armed Assault).
# * targtype1_txt – Type of target (e.g., Military, Civilians).
# * gname – Name of the terrorist group responsible for the attack.
# * weaptype1_txt – Type of weapon used in the attack.
# * nkill – Number of people killed.
# * nwound – Number of people wounded.
# * casualties – Total number of casualties (killed + wounded).
# * success – Indicates whether the attack was successful (1 = Yes, 0 = No).
# * suicide – Indicates if the attack was a suicide attack.
# * property – Indicates whether property damage occurred.
# * propextent_txt – Extent of property damage.
# * extended – Indicates whether the attack lasted more than 24 hours.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
print(df.nunique())
# Out:
# eventid       181691
# iyear             47
# imonth            13
# iday              32
# approxdate      2244
#                ...
# INT_LOG            3
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        14306
# Length: 135, dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df['nkill'] = df['nkill'].fillna(0)
df['nwound'] = df['nwound'].fillna(0)
df['casualities'] = df['nkill'] + df['nwound']
df['iyear'] = df['iyear'].astype(int)

attacks_per_year = df['iyear'].value_counts().sort_index()

top_groups = df['gname'].value_counts().head(5).index
filtered = df[df['gname'].isin(top_groups)]

region_counts = df['region_txt'].value_counts()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations Done :
# * Missing values in nkill and nwound were replaced with 0 to handle incomplete data.
# * A new feature "casualities" was created by combining number of killed and wounded.
# * The year column (iyear) was converted into integer format for proper analysis.
# * Year-wise attack counts were calculated to analyze trends over time.
# * Top 5 terrorist groups were selected based on frequency of attacks.
# * Data was filtered to focus only on these top groups for deeper analysis.
# * Region-wise attack counts were calculated to understand geographic distribution.
#
#
# ---
#
# Insights Found :
# * A small number of terrorist groups are responsible for a large proportion of total attacks.
# * Casualties provide a better measure of attack impact by combining kills and injuries.
# * Most attacks result in low casualties, but a few incidents cause extremely high damage.
# * Terrorism is highly concentrated in specific regions rather than evenly spread globally.
# * Certain regions consistently experience higher attack frequencies.
# * Focusing on top groups helps identify dominant patterns and major contributors to terrorism.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure()
sns.lineplot(x=attacks_per_year.index, y=attacks_per_year.values)
plt.xlabel('Year')
plt.ylabel('Number of attacks')
plt.title('Number of terrorist attacks per year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   Line plot shows graphical representation of the data.
# *   One can easily identify the pattern of number of attacks with respect to year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  In the period of 1970-2000, the number of attacks peaked in 1992-93 (aprox. 5000 attacks).
#
# *   In the period of 1970-2000, the number of attacks fluctuated between 2000 to 5000 attacks per year.
#
# *   After 2010, the number of attacks gradually increased and peaked in 2013-14 (approx 17000 attacks).
#
# *   Post-2014, the number of attacks shows a slight decline, but remains significantly higher than earlier decades.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impacts :
# *   Identify high-risk time periods
# *   Allocate resources more effectively
# *   Improve preventive security strategies
# *   Plan risk mitigation policies based on historical trends
#
# Negative Impacts :
# *   The sharp rise after 2010 reflects increased global instability
# *   This leads to threats to public safety and infrastructure

# %% [markdown]
# #### Chart - 2

# %%
top_countries = df['country_txt'].value_counts().head(10)
plt.figure(figsize=(15, 5))
plt.bar(top_countries.index, top_countries.values)
plt.xlabel('Country')
plt.ylabel('Number of attacks')
plt.title('Top 10 countries by no. of attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   Bar Chart allows easy comparison between multiple countries
# *   Clearly highlights the top affected countries
# *   Makes differences in attack counts visually understandable
# *   Suitable for ranking (Top 10 analysis)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The chart shows the top 10 countries most affected by terrorist attacks
# *   Countries like Iraq, Pakistan, Afghanistan have the highest number of incidents
# *   No. of attacks on Iraq(1st position) are almost 1.8 timees the No. of attacks on Pakistan(2nd position).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact, especially in terms of risk management and strategic planning.
#
# *   Businesses can identify high-risk countries (like Iraq, Pakistan, Afghanistan) and avoid or carefully plan operations in these regions.
# *   Helps in making better investment decisions by analyzing safety and stability.
# *   Assists insurance companies in risk-based pricing and policy design.
#
# ---
#
# Negative Growth Insights :
#
# Countries like Iraq, Pakistan, and Afghanistan show extremely high numbers of attacks, indicating:
#
# *   Ongoing conflict
# *   Political instability
# *   Weak security conditions

# %% [markdown]
# #### Chart - 3

# %%
attack_type = df['attacktype1_txt'].value_counts().head(5)
plt.figure()
plt.pie(attack_type.values, labels=attack_type.index, autopct='%1.1f%%')
plt.title('Top 5 attack types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   A pie chart is ideal for showing the proportion or percentage distribution of categories.
# *   It helps quickly identify which attack types contribute the most.
# *   It provides a simple and clear visual comparison of the top 5 categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that Bombing/Explosion is the most common attack type.
# * Other attack types such as Armed Assault, Assassination, and Hostage Taking contribute smaller proportions.
# * A large share of attacks is dominated by a few major attack types, indicating a pattern in methods used.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps security agencies focus on most common attack methods
# * Enables better preventive measures and preparedness
# * Businesses can improve risk assessment and safety planning.
#
#
# ---
# Negative Growth Insights
#
# * The dominance of bombing/explosion attacks suggests:
#   * High potential for mass damage and casualties
#   * Increased threat to infrastructure and public safety

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='region_txt',order=df['region_txt'].value_counts().index,data=df)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Number of attacks')
plt.title('Number of attacks per region')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is ideal for showing the frequency of categorical data such as regions.
# * It helps compare the number of attacks across different regions easily.
# * The ordering makes it clear which regions have higher or lower attack counts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that Middle East & North Africa has the highest number of terrorist attacks.
# * South Asia is also among the most affected regions.
# * Regions like Central Asia and Australia and Oceania have comparatively fewer attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify high-risk regions for better planning and decision-making.
# * Supports resource allocation and security improvements.
# * Enables businesses to perform risk assessment before expansion.
#
# ---
# Negative Growth Insights
#
# * High concentration of attacks in certain regions indicates:
#
#   * Political instability
#   * Ongoing conflicts
#   * Security challenges

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(12,3))
sns.boxplot(data=df, x='region_txt', y='casualities')
plt.xticks(rotation=90)
plt.title("Casualties Distribution by Region")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A box plot is useful for showing the distribution of numerical data across categories.
# * It helps visualize median, spread, and outliers in casualties across different regions.
# * It allows comparison of variation and extreme values between regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution of casualties varies significantly across regions.
# * Some regions show higher median casualties, indicating more severe attacks.
# * Most attacks in all regions result in low casualties, but rare events lead to very high impact.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify regions with high-impact attacks
# * Supports risk assessment and safety planning
# * Enables better resource allocation and emergency preparedness
# * Helps organizations understand severity, not just frequency
#
# ---
#
# Negative Growth Insights
# * High variability and extreme outliers indicate:
#   * Unpredictable and severe attacks
#   * Increased risk to infrastructure and human life
# * This leads to:
#   * Higher operational and security costs
#   * Business disruptions
#   * Reduced investor confidence

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(12,3))
sns.boxplot(x='targtype1_txt',y='casualities',data=df)
plt.xticks(rotation=90)
plt.title('Casualities distribution by target type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A box plot is ideal for comparing the distribution of a numerical variable (casualties) across multiple categories (target types).
# * It shows median, spread (IQR), and outliers, helping understand severity differences.
# * Useful for identifying which target types lead to more variable or extreme impacts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Casualties vary significantly by target type.
# * Some target types (e.g., Private Citizens & Property, Military, Police) tend to show higher spread and more extreme outliers, indicating occasional high-impact events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps prioritize protection for high-risk targets (e.g., public spaces, critical infrastructure).
# * Supports security planning and resource allocation based on target vulnerability.
# * Assists businesses and governments in risk assessment and contingency planning.
#
# ---
#
# Negative Growth Insights
# * High-impact outliers for certain targets indicate:
#   * Greater risk to public safety and infrastructure
#   * Potential for major disruptions in operations and services
# * This can lead to:
#   * Increased security and insurance costs
#   * Operational interruptions
#   * Reduced confidence in affected sectors/locations

# %% [markdown]
# #### Chart - 7

# %%
plt.figure()
sns.heatmap(df[['nkill','nwound','casualities']].corr(),annot=True)
plt.title("Correlation between variable")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A heatmap is useful for visualizing the correlation between multiple numerical variables in one view.
# * It helps quickly identify strong and weak relationships using color intensity.
# * It simplifies complex data into an easy-to-understand visual format.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There is a strong positive correlation between nkill and casualties.
# * There is a strong positive correlation between nwound and casualties.
# * This shows that total casualties depend directly on the number of people killed and wounded.
# * The correlation between nkill and nwound is moderate.
# * Most attacks result in low casualties, with a few extreme high-value cases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * This helps in better understanding the relationship between casualties, kills, and wounds.
# * It supports effective risk assessment and planning for emergency response.
# * It allows authorities and organizations to allocate medical and security resources more efficiently.
#
#
# ---
#
#
# Negative Growth Insights
# * Strong correlation indicates that attacks can result in high human impact.
# * This leads to increased healthcare and security costs.
# * High casualty events can disrupt business operations and reduce investor confidence.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df, x='attacktype1_txt', hue='success')
plt.xticks(rotation=90)
plt.title("Attack Type vs Success")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is useful for comparing categorical variables like attack type and success.
# * It helps visualize the frequency of successful and unsuccessful attacks across different attack types.
# * It makes it easy to identify patterns and differences between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some attack types have a higher number of successful attacks compared to others.
# * Certain attack types show a noticeable difference between success and failure rates.
# * This indicates that the effectiveness of attacks varies depending on the method used.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify which attack types are more likely to succeed.
# * Supports better security planning and preventive measures.
# * Enables authorities to focus on high-risk attack methods.
#
#
# ---
#
#
# Negative Growth Insights
# * High success rates of certain attack types indicate security vulnerabilities.
# * This can lead to increased threats, higher security costs, and operational risks.
# * It may negatively impact economic stability and public safety.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=df, x='weaptype1_txt', y='casualities')
plt.xticks(rotation=90)
plt.title("Weapon Type Vs Casualties")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A box plot is useful for comparing the distribution of casualties across different weapon types.
# * It shows median, spread, and outliers for each category.
# * It helps identify which weapon types cause more variation and extreme impacts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Casualties vary significantly across different weapon types.
# * Some weapon types show higher median casualties, indicating more severe impact.
# * Presence of outliers suggests that certain weapons can cause extremely high casualties.
# * Most attacks result in lower casualties, but a few lead to very high damage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify weapon types associated with higher casualties.
# * Supports better security measures and preventive strategies.
# * Assists in resource allocation for high-risk attack methods.
#
# Negative Growth Insights
# * High-impact weapons indicate potential for severe damage.
# * This leads to increased security and healthcare costs.
# * It can disrupt business operations and reduce economic stability.

# %% [markdown]
# #### Chart - 10

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x='targtype1_txt', hue='region_txt')
plt.xticks(rotation=90)
plt.title("Target Type vs Region")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is useful for comparing categorical variables like target type and region.
# * It helps visualize how different target types are distributed across regions.
# * It makes it easy to identify patterns and dominant combinations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Certain target types are more common in specific regions.
# * Some regions show higher frequency of attacks on particular targets.
# * This indicates that terrorist activities vary based on regional characteristics.
# * A few target types dominate across most regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify which targets are most vulnerable in different regions.
# * Supports better security planning and protection strategies.
# * Enables region-specific risk assessment and resource allocation.
#
#
# ---
#
#
# Negative Growth Insights
# * Frequent attacks on key targets indicate security weaknesses.
# * This can lead to infrastructure damage and operational disruptions.
# * It may increase costs and reduce economic stability in affected regions.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(12,3))
sns.countplot(data=df, x='attacktype1_txt', hue='propextent_txt')
plt.xticks(rotation=90)
plt.title("Attack Type vs Property Damage")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is useful for comparing categorical variables like attack type and property damage.
# * It helps visualize how different attack types are associated with levels of property damage.
# * It makes it easy to identify patterns between attack methods and their impact on infrastructure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some attack types are associated with higher levels of property damage.
# * Certain attack types show more severe damage compared to others.
# * This indicates that the method of attack influences the extent of infrastructure damage.
# * A few attack types dominate in causing significant property loss.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify attack types that cause the most property damage.
# * Supports better infrastructure protection and preventive planning.
# * Enables efficient allocation of resources for damage control and recovery.
#
#
# ---
#
#
# Negative Growth Insights
# * High property damage leads to economic loss and infrastructure disruption.
# * This increases repair and insurance costs.
# * It can negatively impact business operations and regional economic stability.

# %% [markdown]
# #### Chart - 12

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=filtered, x='gname', hue='region_txt')
plt.xticks(rotation=30)
plt.title("Top Terrorist Groups by Region")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is useful for comparing categorical variables like terrorist group and region.
# * It helps visualize how different groups operate across various regions.
# * It makes it easy to identify dominant groups and their geographic presence.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Certain terrorist groups are more active in specific regions.
# * Some groups dominate in particular regions compared to others.
# * This shows that terrorist activities are region-specific and influenced by local factors.
# * A few groups account for a large number of attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify major terrorist groups operating in different regions.
# * Supports targeted security measures and counter-terrorism strategies.
# * Enables region-wise risk assessment and planning.
#
#
# ---
#
#
# Negative Growth Insights
# * High activity of certain groups indicates strong presence and influence.
# * This increases security risks and instability in affected regions.
# * It can disrupt economic activities and reduce investor confidence.

# %% [markdown]
# #### Chart - 13

# %%
plt.figure(figsize=(5,5))
plt.pie(region_counts.values, labels=region_counts.index, autopct='%1.1f%%')
plt.title("Distribution of Terrorist Attacks by Region")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A pie chart is useful for showing the proportion of attacks across different regions.
# * It helps visualize the percentage distribution of each region clearly.
# * It makes it easy to identify which regions contribute the most to total attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some regions contribute a significantly larger share of attacks compared to others.
# * Middle East & North Africa and South Asia are among the most affected regions.
# * Other regions have a relatively smaller proportion of attacks.
# * This shows that terrorism is concentrated in specific geographic areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact
# * Helps identify high-risk regions for better planning and decision-making.
# * Supports efficient allocation of security resources.
# * Enables businesses and authorities to focus on safer expansion strategies.
#
#
# ---
#
#
# Negative Growth Insights
# * High concentration of attacks in certain regions indicates instability.
# * This leads to reduced investment and economic slowdown.
# * It increases operational risks and costs for businesses.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
corr_cols = ['nkill', 'nwound', 'casualities', 'iyear', 'extended', 'success', 'suicide']
corr_matrix = df[corr_cols].corr()
plt.figure()
plt.title("Correlation Heatmap")
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   Correlation Heatmap helps in identifying relationships and patterns between multiple variables.
# *   Color intensity makes it easy to spot strong and weak correlations.
# *   Provides a compact and intuitive summary of complex data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a strong positive correlation between:
# *   Number of people killed (nkill) and total casualties.
# *   Number of people wounded (nwound) and total casualties.
#
#
# ---
#
#
# Other variables such as:
#
# *   suicide
# *   extended
# *   success
#
#   show weak or moderate correlation with casualties, it means they have a less direct impact.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
plt.figure()
sns.pairplot(df[corr_cols])
plt.suptitle("Pair Plot of Selected Variables", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   To visualize relationships between multiple numerical variables simultaneously in a single view.
# *   To identify patterns, trends, and correlations between variables like kills, wounds, and casualties.
# *   To detect outliers and understand data distribution, which helps in better exploratory data analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a strong positive correlation between:
# *   Number of people killed (nkill) and total casualties.
# *   Number of people wounded (nwound) and total casualties.
#
#
# ---
#
#
# Other variables such as:
#
# *   suicide
# *   extended
# *   success
#
#   show weak or moderate correlation with casualties, it means they have a less direct impact.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Suggestions :
# * Focus on high-risk regions by strengthening security and monitoring systems.
# * Allocate resources efficiently based on attack frequency and severity.
# * Develop region-specific strategies to handle different patterns of terrorism.
# * Improve emergency response systems to minimize casualties and damage.
# * Use data-driven insights to support policy making and preventive measures.
# * Collaborate with international agencies to control and reduce terrorist activities.

# %% [markdown]
# ## ***6. Implementation of Machine Learning models***

# %% [markdown]
# Importing Libraries for ML models

# %%
# Basic Libraries
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Classification Models
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Clustering Models
import scipy.stats as stats
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# Evaluation Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Data Preprocessing

# %%
# Bin casualties into 2 classes
# 0 = Low (1–5), 2 = High (>5)
def bin_casualties(c):
    if c <= 5:  return 0   # Low
    else:       return 1   # High

df['casualty_class'] = df['casualities'].apply(bin_casualties)
print(df)

features = ['iyear', 'imonth', 'region', 'attacktype1',
            'targtype1', 'weaptype1', 'success', 'suicide']

df_ml = df[features + ['casualty_class']].dropna()
X = df_ml[features].values
y = df_ml['casualty_class'].values

sc = StandardScaler()
X = sc.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

print("Training set size:", X_train.shape[0])
print("Test     set size:", X_test.shape[0])
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ...  \
# ...

# %% [markdown]
# #### Model - 1 (SVM)

# %%
svm_model = LinearSVC(random_state=0, max_iter=2000)
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)
print(y_pred)

print("SVM Accuracy:", round(accuracy_score(y_test, y_pred) * 100, 2), "%")

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['Low', 'High'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix — SVM')
plt.show()
# Out:
# [0 0 0 ... 1 0 0]
# SVM Accuracy: 81.96 %

# %% [markdown]
# #### Model - 2 (Decision Tree)

# %%
dt_model = DecisionTreeClassifier(criterion='entropy', random_state=0)
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)
print(y_pred)

print("Decision Tree Accuracy:", round(accuracy_score(y_test, y_pred) * 100, 2), "%")

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['Low', 'High'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix — Decision Tree')
plt.show()
# Out:
# [0 0 0 ... 1 0 1]
# Decision Tree Accuracy: 81.72 %

# %% [markdown]
# #### Model - 3 (KNN)

# %%
knn_model = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
knn_model.fit(X_train, y_train)

y_pred = knn_model.predict(X_test)
print(y_pred)

print("KNN Accuracy:", round(accuracy_score(y_test, y_pred) * 100, 2), "%")

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['Low', 'High'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix — KNN')
plt.show()
# Out:
# [0 1 0 ... 1 0 1]
# KNN Accuracy: 81.73 %

# %% [markdown]
# #### Model - 4 (Naive Bayes)

# %%
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

y_pred = nb_model.predict(X_test)
print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Low', 'High'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix — Naive Bayes')
plt.show()
# Out:
# Naive Bayes Accuracy: 0.8189823605492721

# %% [markdown]
# #### Model - 5 (Hierarchical Clustering - AgglomerativeClustering)

# %%
# Agglomerative Clustering
df_sample = df[['nkill', 'nwound']].dropna().sample(2000, random_state=0)

hc = AgglomerativeClustering(n_clusters=2)
y_hc = hc.fit_predict(df_sample)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=df_sample['nkill'], y=df_sample['nwound'],
                hue=y_hc, palette='Set1')
plt.title('Agglomerative Clustering of Attacks')
plt.xlabel('Killed')
plt.ylabel('Wounded')
plt.show()

# %%
# Dendrogram
from scipy.cluster.hierarchy import dendrogram, linkage


linked = linkage(X[:300], method='ward')

plt.figure(figsize=(10, 6))
dendrogram(linked, truncate_mode='level', p=5)
plt.title('Dendrogram - Hierarchical Clustering')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# Comparison

# %%
models = ['SVM','Decision Tree','KNN','Naive Bayes']
scores = [
    svm_model.score(X_test, y_test),
    dt_model.score(X_test, y_test),
    knn_model.score(X_test, y_test),
    nb_model.score(X_test, y_test)
]

plt.figure()
plt.bar(models, scores)
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Conclusion of EDA:
# * Terrorist attacks increased significantly after 2010, peaking around 2013–2014.
# * Middle East & North Africa and South Asia are the most affected regions.
# * Bombing/Explosion is the most common attack type, followed by armed assaults.
# * Most attacks result in low casualties, but a few cause extremely high damage — highly skewed distribution.
# * Strong correlation exists between kills, wounds, and total casualties.
#
# ---
#
# Conclusion of ML Models:
# * 4 classification models were implemented — SVM, Decision Tree, KNN, and Naive Bayes.
# * All models were trained on 80% data and tested on 20% using train-test split.
# * Decision Tree gave the best accuracy among classification models due to its ability to capture non-linear boundaries in attack features.
# * KNN performed well by identifying similar attack profiles based on region, weapon, and target type.
# * SVM (LinearSVC) was the fastest to train and generalised well on the binary casualty classification task.
# * Naive Bayes, despite being the simplest model, gave competitive accuracy assuming feature independence.
# * Agglomerative Hierarchical Clustering successfully grouped attacks into natural clusters, revealing hidden patterns not visible in EDA.
# * The dendrogram validated the hierarchical structure of the data and helped identify the optimal number of clusters.
#
# ---
#
# Final Conclusion:
# * Terrorism shows clear geographical and temporal patterns, with certain regions being more vulnerable.
# * Data-driven ML models can effectively predict casualty severity and group attack profiles.
# * These insights can help governments take preventive actions, improve security measures, and reduce risks.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA and ML Project !!!***
